# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
iris= pd.read_csv('pandas/Dataset/iris.csv')
iris.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 27    28            5.2           3.5            1.5           0.2
# 2      3            4.7           3.2            1.3           0.2
# 24    25            4.8           3.4            1.9           0.2
# 148  149            6.2           3.4            5.4           2.3
# 85    86            6.0           3.4            4.5           1.6
#
#              Species
# 27       Iris-setosa
# 2        Iris-setosa
# 24       Iris-setosa
# 148   Iris-virginica
# 85   Iris-versicolor

# %%
iris['Species']= iris['Species'].replace({'Iris-versicolor':0, 'Iris-virginica':1, 'Iris-setosa':2})
iris.sample(5)
# Out:
# C:\Users\bgspu\AppData\Local\Temp\ipykernel_12932\1304346175.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   iris['Species']= iris['Species'].replace({'Iris-versicolor':0, 'Iris-virginica':1, 'Iris-setosa':2})
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 2      3            4.7           3.2            1.3           0.2        2
# 142  143            5.8           2.7            5.1           1.9        1
# 42    43            4.4           3.2            1.3           0.2        2
# 117  118            7.7           3.8            6.7           2.2        1
# 104  105            6.5           3.0            5.8           2.2        1

# %%
plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c=iris['Species'], cmap='jet', alpha=0.7)
plt.xlabel('Sepal length')
plt.ylabel('Patal Length')
plt.colorbar()

# %%
plt.figure(figsize=(15,7)) # size change karne ke liye

plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c=iris['Species'], cmap='summer', alpha=0.7) # cmap basically it is thems
plt.title('it is a iris plot')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.colorbar()

# %%
# Annotations

# %%
batters=pd.read_csv('pandas/Dataset/batter.csv')
batters.head(5)
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
sample_df=batters.head(100).sample(25)
sample_df.shape
sample_df
# Out:
#              batter  runs        avg  strike_rate
# 92        STR Binny   880  19.130435   125.714286
# 69       D Padikkal  1260  28.000000   119.205298
# 52      RA Tripathi  1798  27.661538   137.042683
# 72        KM Jadhav  1196  22.148148   119.361277
# 56          PP Shaw  1588  25.206349   143.580470
# 49     Shubman Gill  1900  32.203390   122.186495
# 34        JH Kallis  2427  28.552941   105.936272
# 90           MM Ali   910  23.333333   139.570552
# 68      JM Bairstow  1291  35.861111   138.074866
# 81      LRPL Taylor  1017  25.425000   120.070838
# 95         MS Bisla   798  21.000000   108.276798
# 94       SO Hetmyer   831  30.777778   144.020797
# 85        JA Morkel   975  24.375000   136.938202
# 22         PA Patel  2848  22.603175   116.625717
# 93  Harbhajan Singh   833  15.145455   130.974843
# 35          WP Saha  2427  25.281250   124.397745
# 14        SR Watson  3880  30.793651   134.163209
# 29          M Vijay  2619  25.930693   118.614130
# 21          RR Pant  2851  34.768293   142.550000
# 91         HH Gibbs   886  27.687500   105.854241
# 65          CA Lynn  1329  34.076923   136.447639
# 78          M Vohra  1073  22.354167   125.938967
# 15        MK Pandey  3657  29.731707   117.739858
# 42    KS Williamson  2105  36.293103   123.315759
# 6          CH Gayle  4997  39.658730   142.121729

# %%
plt.figure(figsize=(12,8))
plt.scatter(sample_df['avg'], sample_df['strike_rate'], s=sample_df['runs'])

for i in range (sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i], sample_df['strike_rate'].values[i],sample_df['batter'].values[i])

# %%
# horizontal and vertical lines

plt.figure(figsize=(12,8))
plt.scatter(sample_df['avg'], sample_df['strike_rate'], s=sample_df['runs'])
plt.axhline(130, color='red')
plt.axvline(30, color='red')

for i in range (sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i], sample_df['strike_rate'].values[i],sample_df['batter'].values[i])

# %%
a=[1,3,5,7,9]
b=[2,4,6,8,10]

plt.scatter(a,b)
plt.text(1,2, 'Point 1')
plt.text(3,4, 'Point 2')
plt.text(5,6, 'Point 3')
plt.text(7,8, 'Point 4')
plt.text(9,10, 'Point 5', fontdict={'size':12, 'color':'brown'})
# Out:
# Text(9, 10, 'Point 5')

# %%
# Subplots
batters.head()
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
plt.scatter(batters['avg'], batters['strike_rate'])

# %%
plt.subplot()
# Out:
# <Axes: >

# %%
#plt.figure(figsize=(15,8))

fig, ax=plt.subplots( figsize=(15,6))

ax.scatter(batters['avg'], batters['strike_rate'], color='red', marker='+')
ax.set_title('something')
ax.set_xlabel('avg')
ax.set_ylabel('strike-rate')
fig.show()
# Out:
# C:\Users\bgspu\AppData\Local\Temp\ipykernel_12932\1563455629.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
plt.subplots(nrows=2, ncols=1)
# Out:
# (<Figure size 640x480 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %%
plt.subplots(nrows=2, ncols=2)
# Out:
# (<Figure size 640x480 with 4 Axes>,
#  array([[<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >]], dtype=object))

# %%
fig, ax= plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(10,6))
ax[0].scatter(batters['avg'], batters['strike_rate'], color='red')
ax[1].scatter(batters['avg'], batters['runs'], color='yellow')

ax[0].set_title('avg vs strike rate')
ax[0].set_ylabel('Strike Rate')

ax[1].set_title('Avg vs Runs')
ax[1].set_ylabel('Runs')
ax[1].set_xlabel('Avg')
# Out:
# Text(0.5, 0, 'Avg')

# %%
fig, ax= plt.subplots(nrows=2, ncols=2, figsize=(10,6))


ax[0,0].scatter(batters['avg'], batters['strike_rate'])
ax[0,1].scatter(batters['avg'], batters['runs'])
ax[1,0].hist(batters['avg'])
ax[1,1].hist(batters['runs'])
# Out:
# (array([499.,  40.,  19.,  19.,   9.,   6.,   4.,   4.,   3.,   2.]),
#  array([   0. ,  663.4, 1326.8, 1990.2, 2653.6, 3317. , 3980.4, 4643.8,
#         5307.2, 5970.6, 6634. ]),
#  <BarContainer object of 10 artists>)

# %%
batters.head()
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
# 3D Scatter plots

# %%
batters
fig =plt.figure(figsize=(16,10))

ax=plt.subplot(projection='3d')
ax.scatter3D(batters['runs'], batters['avg'], batters['strike_rate'], marker='+')
ax.set_title('IPL Score Details')

ax.set_xlabel('Runs')
ax.set_ylabel('Avg')
ax.set_zlabel('Strike-rate')
# Out:
# Text(0.5, 0, 'Strike-rate')

# %%
# 3D Line Plot

x=[0,1,5,25]
y=[0,10,13,0]
z=[0,13,20,9]


fig =plt.figure(figsize=(16,10))

ax=plt.subplot(projection='3d')
ax.scatter3D(x,y,z, s=[100,100,100,100])
ax.plot3D(x,y,z, color='red')

# %%
# Surface Plots

x=np.linspace(-10,10,100)
y=np.linspace(-10,10,100)

# %%
xx, yy=np.meshgrid(x,y)
yy.shape
# Out:
# (100, 100)

# %%
z=xx**2+yy**2
z.shape
# Out:
# (100, 100)

# %%
fig=plt.figure(figsize=(12,8))
ax=plt.subplot(projection='3d')
ax.plot_surface(xx,yy,z, cmap='viridis')

# %%
z=np.sin(xx) + np.cos(yy)
fig=plt.figure(figsize=(12,8))
ax=plt.subplot(projection='3d')
p=ax.plot_surface(xx,yy,z, cmap='viridis')
fig.colorbar(p)

# %%
z=np.sin(xx) + np.log(yy)
fig=plt.figure(figsize=(12,8))
ax=plt.subplot(projection='3d')
p=ax.plot_surface(xx,yy,z, cmap='viridis')
fig.colorbar(p)
# Out:
# C:\Users\bgspu\AppData\Local\Temp\ipykernel_12932\982185814.py:1: RuntimeWarning: invalid value encountered in log
#   z=np.sin(xx) + np.log(yy)

# %%
fig=plt.figure(figsize=(12,8))
ax=plt.subplot()
p=ax.contourf(xx,yy,z, cmap='viridis')
fig.colorbar(p)

# %%
# Heatmap

delivery= pd.read_csv('pandas/Dataset/IPL_Ball_by_Ball_2008_2022.csv')
delivery.sample(5)
# Out:
#              ID  innings  overs  ballnumber           batter          bowler  \
# 68931   1136588        1     13           6    KS Williamson       K Gowtham
# 192094   419133        1      7           6          V Kohli  M Muralitharan
# 47954   1178431        1     13           3       RV Uthappa       JJ Bumrah
# 133622   598064        2      6           6  Gurkeerat Singh   R Vinay Kumar
# 162336   548327        2      8           1         CH Gayle         B Kumar
#
#        non-striker extra_type  batsman_run  extras_run  total_run  \
# 68931    MK Pandey        NaN            2           0          2
# 192094   JH Kallis        NaN            1           0          1
# 47954       N Rana        NaN            0           0          0
# 133622   DJ Hussey        NaN            1           0          1
# 162336     V Kohli        NaN            0           0          0
#
#         non_boundary  isWicketDelivery player_out kind fielders_involved  \
# 68931              0                 0        NaN  NaN               NaN
# 192094             0                 0        NaN  NaN               NaN
# 47954              0                 0        NaN  NaN               NaN
# 133622             0                 0        NaN  NaN               NaN
# 162336             0                 0        NaN  NaN               NaN
#
#                         BattingTeam
# 68931           Sunrisers Hyderabad
# 192094  Royal Challengers Bangalore
# 47954         Kolkata Knight Riders
# 133622              Kings XI Punjab
# 162336  Royal Challengers Bangalore

# %%
temp_df=delivery[(delivery['ballnumber'].isin([1,2,3,4,5,6])) & (delivery['batsman_run']==6)]

# %%
grid=temp_df.pivot_table(index='overs', columns='ballnumber', values='batsman_run', aggfunc='count')

# %%
plt.figure(figsize=(20,10))
plt.imshow(grid)
plt.colorbar()

# %%
# Pandas plot()

# on a series
s=pd.Series([1,2,3,4,5,6,7])
s.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
import seaborn as sns
tips=sns.load_dataset('tips')

# %%
tips['size']=tips['size']*100
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner   200
# 1       10.34  1.66    Male     No  Sun  Dinner   300
# 2       21.01  3.50    Male     No  Sun  Dinner   300
# 3       23.68  3.31    Male     No  Sun  Dinner   200
# 4       24.59  3.61  Female     No  Sun  Dinner   400

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
# tips.plot(kind='scatter', x='total_bill', y='tip', title='Cost Analysis', color='red', marker='+', figsize=(10,6),s='size')
tips.plot(kind='scatter',
          x='total_bill',
          y='tip',
          title='Cost Analysis',
          color='red',
          marker='+',
          figsize=(10,6),
          s=tips['size'])
# Out:
# <Axes: title={'center': 'Cost Analysis'}, xlabel='total_bill', ylabel='tip'>

# %%
import numpy as np
import pandas as pd

# %%
pd.Timestamp("2026/04/24")
type(pd.Timestamp('2026-04-24'))
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
pd.Timestamp('2026-04-24')
# Out:
# Timestamp('2026-04-24 00:00:00')

# %%
# only year
pd.Timestamp("2026")
# Out:
# Timestamp('2026-01-01 00:00:00')

# %%
# using text
pd.Timestamp("29 september 2026")
# Out:
# Timestamp('2026-09-29 00:00:00')

# %%
pd.Timestamp('2026, 4, 24')
# Out:
# Timestamp('2026-04-24 00:00:00')

# %%
# providing time also
pd.Timestamp("24th april 2026 12.33am")
# Out:
# Timestamp('2026-04-24 00:00:00')
